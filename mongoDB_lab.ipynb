# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.7.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.6.1)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import json

# %%
uri = "mongodb+srv://user_rw:ExW8FrG8hLEdW4i@it-tep.jybvn6z.mongodb.net/?retryWrites=true&w=majority&appName=IT-tep"
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
# перевірити звязок з MongoDB
try:
    client.admin.command('ping')
    print("Успішне підключення до MongoDB!")
except Exception as e:
    print(e)
# Out:
# Успішне підключення до MongoDB!

# %%
db_name = "media_db"
db = client[db_name]
print("\nБаза даних : ", db)
# Out:
# База даних :  Database(MongoClient(host=['ac-hprolru-shard-00-00.jybvn6z.mongodb.net:27017', 'ac-hprolru-shard-00-02.jybvn6z.mongodb.net:27017', 'ac-hprolru-shard-00-01.jybvn6z.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='IT-tep', authsource='admin', replicaset='atlas-ogrnc9-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x78e4855a9930>), 'media_db')

# %%
collection_name = "movies"

# отримати доступ до колекції чи створити, якщо не існує
collection = db[collection_name]
if collection_name not in db.list_collection_names():
    print("Колекція створена.")
else:
    print("Колекція вже існує.")
# Out:
# Колекція створена.

# %%
# завантажити дані х JSON-файлу
with open('movies.json', 'r') as file:
    data = json.load(file)
    # вставити дані в колекцію
    collection.insert_many(data)
    print("Дані завантажені у MongoDB.")
# Out:
# Дані завантажені у MongoDB.

# %%
count = collection.count_documents({})
print(f"Кількість фільмів у колекції '{collection_name}': {count}")
# Out:
# Кількість фільмів у колекції 'movies': 36273

# %%
# пошук записів по рокам
query = {"year": {"$gte": 2000, "$lte": 2020}}
print(f"Кількість фільмів у колекції '{collection_name}' за період 2000-2020 : {collection.count_documents(query)}")
# Out:
# Кількість фільмів у колекції 'movies' за період 2000-2020 : 5217

# %%
actor = "Tom Cruise"
query = {"cast": actor}
print(f"Кількість фільмів за участю '{actor}' : {collection.count_documents(query)}")
# Out:
# Кількість фільмів за участю 'Tom Cruise' : 45

# %%
# закрити  підключення
client.close()
